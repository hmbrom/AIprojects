# %% [markdown]
# ### Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Creating a polynomial dataset and dividing| into X and Y variables

# %%
X = 6 * np.random.rand(200,1) -3
Y = 0.8*X**2 + 0.9*X + 2 + np.random.randn(200,1)

# %% [markdown]
# ### Visualization of data points

# %%
plt.plot(X,Y, 'b.')
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %% [markdown]
# ### Splitting the dataset into training and testing sets

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 3)

# %% [markdown]
# ### Standardization of Data

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.transform(X_test)

# %% [markdown]
# ### Polynomial Features

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

poly = PolynomialFeatures(include_bias= True)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

# %% [markdown]
# ### Linear Regression on Polynomial Features

# %%
lr = LinearRegression()
lr.fit(X_train_poly, Y_train)
# Out:
# LinearRegression()

# %%
pred = lr.predict(X_test_poly)

# %% [markdown]
# ### Evaluation of model

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

print('mae:',mean_absolute_error(pred, Y_test))
print('r2:', r2_score(pred, Y_test))
# Out:
# mae: 0.6869150554715944
# r2: 0.8827062087980634

# %%
plt.scatter(X_test,pred, label = "Predicted")
plt.scatter(X_test, Y_test, color = "red",label = "Actual")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.show()

# %%
print(lr.coef_)
# Out:
# [[0.         0.91699526 0.79347029]]

# %%
print(lr.intercept_)
# Out:
# [2.05343064]
