# %%
#Importing Pandas
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Reading the csv file and storing it in df
df = pd.read_csv('Salary_dataset.csv')

# %%
df.shape
# Out:
# (30, 3)

# %% [markdown]
# This dataset has 30 rows and 3 columns

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       30 non-null     int64
#  1   YearsExperience  30 non-null     float64
#  2   Salary           30 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 852.0 bytes

# %% [markdown]
# Since, we do not need the first unnamed column. Let us remove it.

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0
# 2              1.6  37732.0
# 3              2.1  43526.0
# 4              2.3  39892.0

# %% [markdown]
# Let us divide the dataframe into x and y features

# %%
# x = df.iloc[:,[0]]
# y = df.iloc[:,[-1]]
x= df[["YearsExperience"]]
y = df[["Salary"]]

# %%
y.head()
# Out:
#     Salary
# 0  39344.0
# 1  46206.0
# 2  37732.0
# 3  43526.0
# 4  39892.0

# %%
x.head()
# Out:
#    YearsExperience
# 0              1.2
# 1              1.4
# 2              1.6
# 3              2.1
# 4              2.3

# %% [markdown]
# Divide the dataset into train and test splits

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
len(x_train)
# Out:
# 24

# %%
len(x_test)
# Out:
# 6

# %%
len(y_train)
# Out:
# 24

# %%
len(y_test)
# Out:
# 6

# %% [markdown]
# Let us Scale these features using the standard scalar

# %%
#Feature Scaling using Standard Scaler
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %% [markdown]
# Train the model

# %%
#Train the model
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#Predictions
y_pred = regressor.predict(x_test)

# %%
y_pred
# Out:
# array([[ 54331.88192488],
#        [ 62719.58856472],
#        [ 60855.65375587],
#        [ 92542.54550637],
#        [107454.0239772 ],
#        [ 46876.14268947]])

# %%
y_test = np.array(y_test)

# %%
#Plotting of y_test vs y_pred

plt.plot(y_pred, color='blue', label='prediction')
plt.plot(y_test, color='red', label='test')
plt.title('Actual vs Prediction')
plt.ylabel('Salary')
plt.xlabel('Experience (Years)')
plt.legend()
plt.show()

# %% [markdown]
# Evaluation the model performance

# %%
#Model Evaluation
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import root_mean_squared_error
from sklearn.metrics import r2_score

print('mae:', mean_absolute_error(y_test,y_pred))
print('rmse:', root_mean_squared_error(y_test,y_pred))
print('r2_score:', r2_score(y_test,y_pred))
# Out:
# mae: 4112.959412027726
# rmse: 4709.719971823454
# r2_score: 0.9625816901813793
